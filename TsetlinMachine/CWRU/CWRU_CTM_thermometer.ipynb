# %%
pip install pyTsetlinMachine
# Out:
# Requirement already satisfied: pyTsetlinMachine in /opt/conda/lib/python3.11/site-packages (0.6.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install PyTsetlinMachineCUDA
# Out:
# Requirement already satisfied: PyTsetlinMachineCUDA in /opt/conda/lib/python3.11/site-packages (0.1.9)
# Note: you may need to restart the kernel to use updated packages.

# %%
from PyTsetlinMachineCUDA.tm import MultiClassConvolutionalTsetlinMachine2D
import PyTsetlinMachineCUDA.tm
import pyTsetlinMachine
from sklearn.metrics import accuracy_score, f1_score
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
import math
from scipy import stats
from scipy.signal import spectrogram
from scipy.io import loadmat
from sklearn.model_selection import train_test_split
import os
from tqdm import tqdm
import seaborn as sns
import pandas as pd
import random
from scipy.ndimage import zoom
from sklearn.metrics import confusion_matrix
import json

# %%
json_file = 'TM_CWRU_CTM_thermometer_avg.json' # Stores the result in here
directory_path = "../data/CWRU/Faulty" # Path to CWRU files

# %%
def load_mat_spectrogram(mat_file_path, num_bits, std_num=3, target_shape=(245, 1000)):
    """
    Load a spectrogram from a MATLAB file, process it through stretching, standardizing, normalizing, and
    encode it using thermometer encoding.

    Parameters:
    mat_file_path (str): Path to the MATLAB file containing the spectrogram.
    num_bits (int): Number of bits for thermometer encoding.
    std_num (int): Number of standard deviations for clipping during standardization.
    target_shape (tuple): Desired output shape (height, width) of the spectrogram.

    Returns:
    np.array: A array representing the encoded spectrogram.
    """
    # Load the spectrogram from the specified .mat file.
    mat_contents = scipy.io.loadmat(mat_file_path)
    spectrogram = mat_contents['spectrogram']

    # Calculate the zoom factors to resize the spectrogram to the target shape.
    zoom_factor_y = target_shape[0] / spectrogram.shape[0]
    zoom_factor_x = target_shape[1] / spectrogram.shape[1]

    # Stretch the spectrogram to the target shape using interpolation.
    stretched_y = zoom(spectrogram, (zoom_factor_y, zoom_factor_x))

    # Clip the stretched spectrogram's values to limit extreme deviations.
    avg_y = np.mean(stretched_y)
    std_y = np.std(stretched_y)
    clean_y = np.clip(stretched_y, avg_y - std_num * std_y, avg_y + std_num * std_y)

    # Normalize the clipped values to range between 0 and 1.
    clean_y_min = np.min(clean_y)
    clean_y_max = np.max(clean_y)
    norm_y = (clean_y - clean_y_min) / (clean_y_max - clean_y_min)

    # Define the thermometer encoding function.
    def thermometer_encode(values, num_bits):
        # Generate threshold values for encoding.
        thresholds = np.linspace(0, 1, num_bits + 1, endpoint=False)[1:]
        
        # Prepare values for vectorized comparison against thresholds.
        values_expanded = values[:, :, np.newaxis]
        
        # Perform vectorized comparison to generate encoded array.
        encoded = (values_expanded >= thresholds).astype(int)
        
        return encoded

    # Apply thermometer encoding to the normalized spectrogram.
    encoded_spectrogram = thermometer_encode(norm_y, num_bits)
    
    # Transpose to adjust dimensions for further processing.
    encoded_spectrogram = np.transpose(encoded_spectrogram, (1, 0, 2))
    return encoded_spectrogram

# %%
def spectrogram_size(mat_file_path):
    """
    Calculate the number of time frames in a spectrogram stored within a MATLAB file.

    Parameters:
    mat_file_path (str): The file path to the .mat file containing the spectrogram data.

    Returns:
    int: The number of time frames in the spectrogram.
    """
    # Load the spectrogram data from a .mat file.
    mat_contents = scipy.io.loadmat(mat_file_path)
    
    # Access the spectrogram data from the file contents.
    spectrogram = mat_contents['spectrogram']
    
    # Return the number of time frames, which is the number of rows in the spectrogram array.
    return spectrogram.shape[0]

# %%
def process_spectrograms(labels, file_paths, k_width, bits):
    """
    Process spectrogram files into sequences for machine learning models. This involves reshaping each spectrogram
    based on a window width (k_width) and the number of bits used in encoding.

    Parameters:
    labels (list): A list of labels corresponding to each spectrogram.
    file_paths (list): A list of paths to spectrogram files.
    k_width (int): The number of consecutive slices to include in each window of the output array.
    bits (int): The number of bits used in encoding the spectrogram, influencing the number of channels.

    Returns:
    tuple: A tuple containing two numpy arrays:
           - x_data: Array of reshaped spectrogram data for model input.
           - y_data: Array of labels corresponding to each window of spectrogram data.
    """
    x_data = []
    y_data = []

    # Process each file and label pair.
    for label, path in zip(labels, file_paths):
        # Load the spectrogram which is already encoded into bit format.
        spectrogram = load_mat_spectrogram(path, bits)
        print("Spectrogram shape before processing:", spectrogram.shape)

        # Dimensions of the loaded spectrogram
        time_slices, frequency_bins, channels = spectrogram.shape

        # Adjust the number of time slices to ensure it is divisible by k_width.
        if time_slices % k_width != 0:
            spectrogram = spectrogram[:-(time_slices % k_width)]

        # Calculate the new number of time slices after trimming.
        new_time_slices = time_slices - (time_slices % k_width)

        # Initialize an empty array for storing reshaped data.
        reshaped_data = np.empty((new_time_slices - k_width + 1, k_width, frequency_bins, channels))

        # Populate the reshaped data array with windows of spectrogram slices.
        for i in range(new_time_slices - k_width + 1):
            reshaped_data[i] = spectrogram[i:i + k_width]

        # Append the reshaped spectrogram and corresponding label to the output lists.
        x_data.append(reshaped_data)
        y_data.append(label)

    # Convert lists to numpy arrays for handling varying sizes.
    x_data = np.array(x_data, dtype=object)
    y_data = np.array(y_data, dtype=object)

    return x_data, y_data

# %%
# Define sets for different types of faults identified by specific ball and roller positions in bearings
ball_numbers = {123, 124, 125, 190, 191, 192, 227, 228, 229}
inner_numbers = {110, 111, 112, 175, 176, 177, 214, 215, 217}
outer_numbers = {136, 137, 138, 202, 203, 204, 239, 240, 241}
test = [229,217,138]
labels = []  
# Number of bits for thermometer encoding
bits = 8 
# Define window size of the data augmentation
k_width = 2
min_spectogram_height = 200
file_paths = [

]

labels_test = []
file_paths_test = [

]

c = 0

# Process each file in the directory
for filename in os.listdir(directory_path):
    if c > 36:  # Limit the number of files processed
        break

    # Extract the numeric part of the filename
    digit_str = ''.join(filter(str.isdigit, filename))
    if not digit_str:  # Ignore files without numbers
        continue
    number = int(digit_str)

    # Assign labels based on the number extracted from the filename
    if number in ball_numbers:
        label = 0
    elif number in inner_numbers:
        label = 1
    elif number in outer_numbers:
        label = 2
    else:
        label = None  # Ignore files that don't match the expected categories
    
    if label is not None:  # Only process files with a valid label
        file_path = os.path.join(directory_path, filename)
        if number not in test:
            # Add the file to the training set if it meets the height requirement
            if spectrogram_size(file_path) > min_spectogram_height:
                labels.append(label)
                file_paths.append(file_path)
            else:
                # Output the file path if the height is insufficient (for debugging)
                print(file_path)
            c += 1
        else:
            # Add the file to the testing set if it meets the height requirement
            file_path_test = os.path.join(directory_path, filename)
            if spectrogram_size(file_path_test) > min_spectogram_height:
                labels_test.append(label)
                file_paths_test.append(file_path_test)
            else:
                # Output details for debugging
                print(spectrogram_size(file_path_test))
                print(file_path_test)
            c += 1


# Process spectrograms and prepare data arrays
x_data, y_data = process_spectrograms(labels, file_paths, k_width, bits)
x_data_test, y_data_test = process_spectrograms(labels_test, file_paths_test, k_width, bits)

# Combine all sequence data into a single array for training and testing
x_data = np.vstack(x_data)
x_data_test = np.vstack(x_data_test)

# Reshape data into a flat format suitable for model input
flattened_data = x_data.reshape(-1, x_data.shape[1] * x_data.shape[2], x_data.shape[3])
flattened_data_test = x_data_test.reshape(-1, x_data_test.shape[1] * x_data_test.shape[2], x_data_test.shape[3])

# Repeat labels for each segment in the processed data
repeated_y_data = np.repeat(y_data, 1000 - (k_width - 1)).reshape(-1, 1000 - (k_width - 1))
repeated_y_data_test = np.repeat(y_data_test, 1000 - (k_width - 1)).reshape(-1, 1000 - (k_width - 1))

# Flatten label arrays for consistency with the input data
repeated_y_data = repeated_y_data.flatten()
repeated_y_data_test = repeated_y_data_test.flatten()
# Out:
# Spectrogram shape before processing: (1000, 245, 8)
# Spectrogram shape before processing: (1000, 245, 8)
# Spectrogram shape before processing: (1000, 245, 8)
# Spectrogram shape before processing: (1000, 245, 8)
# Spectrogram shape before processing: (1000, 245, 8)
# Spectrogram shape before processing: (1000, 245, 8)
# Spectrogram shape before processing: (1000, 245, 8)
# Spectrogram shape before processing: (1000, 245, 8)
# Spectrogram shape before processing: (1000, 245, 8)
# Spectrogram shape before processing: (1000, 245, 8)
# Spectrogram shape before processing: (1000, 245, 8)
# Spectrogram shape before processing: (1000, 245, 8)
# Spectrogram shape before processing: (1000, 245, 8)
# Spectrogram shape before processing: (1000, 245, 8)
# Spectrogram shape before processing: (1000, 245, 8)
# Spectrogram shape before processing: (1000, 245, 8)
# Spectrogram shape before processing: (1000, 245, 8)
# Spectrogram shape before processing: (1000, 245, 8)
# Spectrogram shape before processing: (1000, 245, 8)
# Spectrogram shape before processing: (1000, 245, 8)
# Spectrogram shape before processing: (1000, 245, 8)
# Spectrogram shape before processing: (1000, 245, 8)
# Spectrogram shape before processing: (1000, 245, 8)
# Spectrogram shape before processing: (1000, 245, 8)
# Spectrogram shape before processing: (1000, 245, 8)
# Spectrogram shape before processing: (1000, 245, 8)
# Spectrogram shape before processing: (1000, 245, 8)

# %%
print(x_data.shape)
print(x_data_test.shape)
print(flattened_data.shape)
print(flattened_data_test.shape)
print(repeated_y_data.shape)
print(repeated_y_data_test.shape)
# Out:
# (23976, 2, 245, 8)
# (2997, 2, 245, 8)
# (23976, 490, 8)
# (2997, 490, 8)
# (23976,)
# (2997,)

# %%
C = flattened_data.shape[1]
T = np.power((C/0.8377),1/2.2099)
s = 2.534*np.log((C/3.7579))

# Split your combined dataset into training and test sets
X_train, X_test, y_train, y_test = train_test_split(flattened_data, repeated_y_data, test_size=0.2)

training_steps = 75
epochs = 1
runs = 1 # Number of runs in total the Tsetlin Machine will do

for i in range(runs):
    epoch_accuracies = []
    epoch_unseen = []
    tm = MultiClassConvolutionalTsetlinMachine2D(int(C), T, s,(int(flattened_data.shape[1]),bits)) # Init the Tsetlin Machine
    for epoch in range(training_steps):
        tm.fit(X_train, y_train, epochs=epochs, incremental=True)  # Train for epoch
        
        Y_pred = tm.predict(X_test)
    
        y_test = y_test.astype(Y_pred.dtype)
        
        #print(f"y_test dtype: {y_test.dtype}, Y_pred dtype: {Y_pred.dtype}")
        accuracy = accuracy_score(y_test, Y_pred)
        print(f'Epoch {epoch+1} Accuracy: {accuracy * 100:.2f}%')
        epoch_accuracies.append(accuracy)
        a_s = accuracy
    
        repeated_y_data_test = repeated_y_data_test.astype(Y_pred.dtype)
        Y_pred = tm.predict(flattened_data_test)
        accuracy = accuracy_score(repeated_y_data_test, Y_pred)
        print(f'Epoch {epoch+1} Accuracy for unseendata: {accuracy * 100:.2f}%')
        epoch_unseen.append(accuracy)
        a_u = accuracy
        
        accuracy_data = {
            "epoch_accuracies": epoch_accuracies,
            "epoch_unseen": epoch_unseen
        }

        try:
            with open(json_file, 'r') as file:
                data = json.load(file)
        except (FileNotFoundError, json.JSONDecodeError):
            data = {'training_run': [],}
            with open(json_file, 'w') as file:  
                json.dump(data, file)  

        data['training_run'].append({
            'seendata': a_s,
            'unseendata': a_u,
        })
        
        with open(json_file, 'w') as f:
            json.dump(data, f, indent=4)
    

# Now you can plot the accuracy over epochs if you want
data = pd.DataFrame({
    'Epoch': range(1, training_steps + 1),
    'Accuracy': epoch_accuracies
})

sns.set_theme(style="whitegrid")
plt.figure(figsize=(10, 6))
plot = sns.lineplot(x='Epoch', y='Accuracy', data=data, marker='o', palette="tab10", linewidth=2.5)
plot.set(xlabel='Epoch', ylabel='Accuracy', title='Accuracy over Epochs')
# plt.savefig('../plot/accuracy_plot.png')  # Option for saving plot
plt.show()

data_unseen = pd.DataFrame({
    'Epoch': range(1, training_steps + 1),
    'Accuracy': epoch_unseen
})
sns.set_theme(style="whitegrid")
plt.figure(figsize=(10, 6))
plot = sns.lineplot(x='Epoch', y='Accuracy', data=data_unseen, marker='o', palette="tab10", linewidth=2.5)
plot.set(xlabel='Epoch', ylabel='Accuracy', title='Accuracy over Epochs with unseendata')
# plt.savefig('../plot/accuracy_plot_unseen.png')  # Option for saving plot

plt.show()
# Out:
# Epoch 1 Accuracy: 88.49%
# Epoch 1 Accuracy for unseendata: 93.13%
# Epoch 2 Accuracy: 93.10%
# Epoch 2 Accuracy for unseendata: 91.89%
# Epoch 3 Accuracy: 94.22%
# Epoch 3 Accuracy for unseendata: 95.43%
# Epoch 4 Accuracy: 95.16%
# Epoch 4 Accuracy for unseendata: 95.93%
# Epoch 5 Accuracy: 95.27%
# Epoch 5 Accuracy for unseendata: 96.90%
# Epoch 6 Accuracy: 95.25%
# Epoch 6 Accuracy for unseendata: 96.53%
# Epoch 7 Accuracy: 95.33%
# Epoch 7 Accuracy for unseendata: 95.43%
# Epoch 8 Accuracy: 95.64%
# Epoch 8 Accuracy for unseendata: 96.10%
# Epoch 9 Accuracy: 95.89%
# Epoch 9 Accuracy for unseendata: 95.63%
# Epoch 10 Accuracy: 95.60%
# Epoch 10 Accuracy for unseendata: 94.26%
# Epoch 11 Accuracy: 96.00%
# Epoch 11 Accuracy for unseendata: 97.36%
# Epoch 12 Accuracy: 95.87%
# Epoch 12 Accuracy for unseendata: 97.20%
# Epoch 13 Accuracy: 95.85%
# Epoch 13 Accuracy for unseendata: 96.70%
# Epoch 14 Accuracy: 96.33%
# Epoch 14 Accuracy for unseendata: 95.73%
# Epoch 15 Accuracy: 96.68%
# Epoch 15 Accuracy for unseendata: 96.83%
# Epoch 16 Accuracy: 96.71%
# Epoch 16 Accuracy for unseendata: 97.10%
# Epoch 17 Accuracy: 96.77%
# Epoch 17 Accuracy for unseendata: 97.20%
# Epoch 18 Accuracy: 96.83%
# Epoch 18 Accuracy for unseendata: 97.20%
# Epoch 19 Accuracy: 96.75%
# Epoch 19 Accuracy for unseendata: 96.70%
# Epoch 20 Accuracy: 96.68%
# Epoch 20 Accuracy for unseendata: 97.16%
# Epoch 21 Accuracy: 96.62%
# Epoch 21 Accuracy for unseendata: 97.96%
# Epoch 22 Accuracy: 96.85%
# Epoch 22 Accuracy for unseendata: 97.30%
# Epoch 23 Accuracy: 96.64%
# Epoch 23 Accuracy for unseendata: 98.20%
# Epoch 24 Accuracy: 96.71%
# Epoch 24 Accuracy for unseendata: 98.23%
# Epoch 25 Accuracy: 97.10%
# Epoch 25 Accuracy for unseendata: 97.56%
# Epoch 26 Accuracy: 96.96%
# Epoch 26 Accuracy for unseendata: 96.66%
# Epoch 27 Accuracy: 96.75%
# Epoch 27 Accuracy for unseendata: 96.86%
# Epoch 28 Accuracy: 96.71%
# Epoch 28 Accuracy for unseendata: 96.56%
# Epoch 29 Accuracy: 96.98%
# Epoch 29 Accuracy for unseendata: 96.63%
# Epoch 30 Accuracy: 96.85%
# Epoch 30 Accuracy for unseendata: 97.56%
# Epoch 31 Accuracy: 96.62%
# Epoch 31 Accuracy for unseendata: 98.03%
# Epoch 32 Accuracy: 96.77%
# Epoch 32 Accuracy for unseendata: 98.50%
# Epoch 33 Accuracy: 96.75%
# Epoch 33 Accuracy for unseendata: 98.57%
# Epoch 34 Accuracy: 96.89%
# Epoch 34 Accuracy for unseendata: 97.23%
# Epoch 35 Accuracy: 96.81%
# Epoch 35 Accuracy for unseendata: 95.76%
# Epoch 36 Accuracy: 97.00%
# Epoch 36 Accuracy for unseendata: 95.10%
# Epoch 37 Accuracy: 97.12%
# Epoch 37 Accuracy for unseendata: 95.63%
# Epoch 38 Accuracy: 96.93%
# Epoch 38 Accuracy for unseendata: 95.73%
# Epoch 39 Accuracy: 96.85%
# Epoch 39 Accuracy for unseendata: 96.06%
# Epoch 40 Accuracy: 96.75%
# Epoch 40 Accuracy for unseendata: 97.46%
# Epoch 41 Accuracy: 96.77%
# Epoch 41 Accuracy for unseendata: 98.57%
# Epoch 42 Accuracy: 96.85%
# Epoch 42 Accuracy for unseendata: 98.06%
# Epoch 43 Accuracy: 97.00%
# Epoch 43 Accuracy for unseendata: 97.70%
# Epoch 44 Accuracy: 96.91%
# Epoch 44 Accuracy for unseendata: 97.66%
# Epoch 45 Accuracy: 97.31%
# Epoch 45 Accuracy for unseendata: 96.40%
# Epoch 46 Accuracy: 97.23%
# Epoch 46 Accuracy for unseendata: 95.83%
# Epoch 47 Accuracy: 97.14%
# Epoch 47 Accuracy for unseendata: 95.66%
# Epoch 48 Accuracy: 97.16%
# Epoch 48 Accuracy for unseendata: 95.33%
# Epoch 49 Accuracy: 96.93%
# Epoch 49 Accuracy for unseendata: 95.56%
# Epoch 50 Accuracy: 97.10%
# Epoch 50 Accuracy for unseendata: 96.96%
# Epoch 51 Accuracy: 96.75%
# Epoch 51 Accuracy for unseendata: 97.86%
# Epoch 52 Accuracy: 96.71%
# Epoch 52 Accuracy for unseendata: 98.33%
# Epoch 53 Accuracy: 97.12%
# Epoch 53 Accuracy for unseendata: 98.33%
# Epoch 54 Accuracy: 96.98%
# Epoch 54 Accuracy for unseendata: 97.83%
# Epoch 55 Accuracy: 97.35%
# Epoch 55 Accuracy for unseendata: 97.23%
# Epoch 56 Accuracy: 97.12%
# Epoch 56 Accuracy for unseendata: 97.13%
# Epoch 57 Accuracy: 97.00%
# Epoch 57 Accuracy for unseendata: 96.23%
# Epoch 58 Accuracy: 97.27%
# Epoch 58 Accuracy for unseendata: 94.69%
# Epoch 59 Accuracy: 97.23%
# Epoch 59 Accuracy for unseendata: 93.06%
# Epoch 60 Accuracy: 96.93%
# Epoch 60 Accuracy for unseendata: 91.66%
# Epoch 61 Accuracy: 97.16%
# Epoch 61 Accuracy for unseendata: 92.03%
# Epoch 62 Accuracy: 97.04%
# Epoch 62 Accuracy for unseendata: 94.69%
# Epoch 63 Accuracy: 96.85%
# Epoch 63 Accuracy for unseendata: 95.80%
# Epoch 64 Accuracy: 96.93%
# Epoch 64 Accuracy for unseendata: 95.26%
# Epoch 65 Accuracy: 97.10%
# Epoch 65 Accuracy for unseendata: 96.66%
# Epoch 66 Accuracy: 97.23%
# Epoch 66 Accuracy for unseendata: 96.66%
# Epoch 67 Accuracy: 97.19%
# Epoch 67 Accuracy for unseendata: 97.10%
# Epoch 68 Accuracy: 97.33%
# Epoch 68 Accuracy for unseendata: 96.93%
# Epoch 69 Accuracy: 97.25%
# Epoch 69 Accuracy for unseendata: 97.16%
# Epoch 70 Accuracy: 97.27%
# Epoch 70 Accuracy for unseendata: 96.70%
# Epoch 71 Accuracy: 97.21%
# Epoch 71 Accuracy for unseendata: 96.70%
# Epoch 72 Accuracy: 97.10%
# Epoch 72 Accuracy for unseendata: 96.76%
# Epoch 73 Accuracy: 97.19%
# Epoch 73 Accuracy for unseendata: 95.96%
# Epoch 74 Accuracy: 96.93%
# Epoch 74 Accuracy for unseendata: 95.90%
# Epoch 75 Accuracy: 97.14%
# Epoch 75 Accuracy for unseendata: 96.03%
# Epoch 1 Accuracy: 88.99%
# Epoch 1 Accuracy for unseendata: 91.49%
# Epoch 2 Accuracy: 92.87%
# Epoch 2 Accuracy for unseendata: 93.09%
# Epoch 3 Accuracy: 93.89%
# Epoch 3 Accuracy for unseendata: 93.49%
# Epoch 4 Accuracy: 94.91%
# Epoch 4 Accuracy for unseendata: 95.53%
# Epoch 5 Accuracy: 95.16%
# Epoch 5 Accuracy for unseendata: 95.23%
# Epoch 6 Accuracy: 95.27%
# Epoch 6 Accuracy for unseendata: 95.40%
# Epoch 7 Accuracy: 95.93%
# Epoch 7 Accuracy for unseendata: 95.46%
# Epoch 8 Accuracy: 95.70%
# Epoch 8 Accuracy for unseendata: 94.83%
# Epoch 9 Accuracy: 96.04%
# Epoch 9 Accuracy for unseendata: 96.40%
# Epoch 10 Accuracy: 96.04%
# Epoch 10 Accuracy for unseendata: 97.03%
# Epoch 11 Accuracy: 95.89%
# Epoch 11 Accuracy for unseendata: 98.43%
# Epoch 12 Accuracy: 96.16%
# Epoch 12 Accuracy for unseendata: 98.10%
# Epoch 13 Accuracy: 96.48%
# Epoch 13 Accuracy for unseendata: 96.03%
# Epoch 14 Accuracy: 96.62%
# Epoch 14 Accuracy for unseendata: 95.96%
# Epoch 15 Accuracy: 96.43%
# Epoch 15 Accuracy for unseendata: 96.10%
# Epoch 16 Accuracy: 96.29%
# Epoch 16 Accuracy for unseendata: 97.76%
# Epoch 17 Accuracy: 96.18%
# Epoch 17 Accuracy for unseendata: 97.36%
# Epoch 18 Accuracy: 95.79%
# Epoch 18 Accuracy for unseendata: 96.90%
# Epoch 19 Accuracy: 96.18%
# Epoch 19 Accuracy for unseendata: 96.00%
# Epoch 20 Accuracy: 96.14%
# Epoch 20 Accuracy for unseendata: 92.46%
# Epoch 21 Accuracy: 96.54%
# Epoch 21 Accuracy for unseendata: 93.26%
# Epoch 22 Accuracy: 96.37%
# Epoch 22 Accuracy for unseendata: 93.69%
# Epoch 23 Accuracy: 96.48%
# Epoch 23 Accuracy for unseendata: 96.53%
# Epoch 24 Accuracy: 96.16%
# Epoch 24 Accuracy for unseendata: 98.67%
# Epoch 25 Accuracy: 96.81%
# Epoch 25 Accuracy for unseendata: 98.50%
# Epoch 26 Accuracy: 96.56%
# Epoch 26 Accuracy for unseendata: 98.23%
# Epoch 27 Accuracy: 96.50%
# Epoch 27 Accuracy for unseendata: 97.70%
# Epoch 28 Accuracy: 96.87%
# Epoch 28 Accuracy for unseendata: 96.96%
# Epoch 29 Accuracy: 97.14%
# Epoch 29 Accuracy for unseendata: 96.90%
# Epoch 30 Accuracy: 97.31%
# Epoch 30 Accuracy for unseendata: 97.23%
# Epoch 31 Accuracy: 97.19%
# Epoch 31 Accuracy for unseendata: 97.00%
# Epoch 32 Accuracy: 96.91%
# Epoch 32 Accuracy for unseendata: 97.70%
# Epoch 33 Accuracy: 97.00%
# Epoch 33 Accuracy for unseendata: 98.00%
# Epoch 34 Accuracy: 97.16%
# Epoch 34 Accuracy for unseendata: 97.40%
# Epoch 35 Accuracy: 96.91%
# Epoch 35 Accuracy for unseendata: 97.10%
# Epoch 36 Accuracy: 97.10%
# Epoch 36 Accuracy for unseendata: 96.56%
# Epoch 37 Accuracy: 97.04%
# Epoch 37 Accuracy for unseendata: 97.63%
# Epoch 38 Accuracy: 97.12%
# Epoch 38 Accuracy for unseendata: 97.70%
# Epoch 39 Accuracy: 97.21%
# Epoch 39 Accuracy for unseendata: 97.66%
# Epoch 40 Accuracy: 97.12%
# Epoch 40 Accuracy for unseendata: 97.90%
# Epoch 41 Accuracy: 97.08%
# Epoch 41 Accuracy for unseendata: 98.33%
# Epoch 42 Accuracy: 97.06%
# Epoch 42 Accuracy for unseendata: 98.20%
# Epoch 43 Accuracy: 97.00%
# Epoch 43 Accuracy for unseendata: 98.20%
# Epoch 44 Accuracy: 96.83%
# Epoch 44 Accuracy for unseendata: 97.33%
# Epoch 45 Accuracy: 96.75%
# Epoch 45 Accuracy for unseendata: 97.03%
# Epoch 46 Accuracy: 96.89%
# Epoch 46 Accuracy for unseendata: 96.60%
# Epoch 47 Accuracy: 97.00%
# Epoch 47 Accuracy for unseendata: 97.10%
# Epoch 48 Accuracy: 97.14%
# Epoch 48 Accuracy for unseendata: 96.46%
# Epoch 49 Accuracy: 97.19%
# Epoch 49 Accuracy for unseendata: 96.93%
# Epoch 50 Accuracy: 97.21%
# Epoch 50 Accuracy for unseendata: 98.10%
# Epoch 51 Accuracy: 97.19%
# Epoch 51 Accuracy for unseendata: 98.13%
# Epoch 52 Accuracy: 96.85%
# Epoch 52 Accuracy for unseendata: 98.26%
# Epoch 53 Accuracy: 96.73%
# Epoch 53 Accuracy for unseendata: 97.76%
# Epoch 54 Accuracy: 96.89%
# Epoch 54 Accuracy for unseendata: 98.16%
# Epoch 55 Accuracy: 97.48%
# Epoch 55 Accuracy for unseendata: 97.16%
# Epoch 56 Accuracy: 97.46%
# Epoch 56 Accuracy for unseendata: 96.56%
# Epoch 57 Accuracy: 97.23%
# Epoch 57 Accuracy for unseendata: 97.56%
# Epoch 58 Accuracy: 97.12%
# Epoch 58 Accuracy for unseendata: 96.76%
# Epoch 59 Accuracy: 97.21%
# Epoch 59 Accuracy for unseendata: 95.23%
# Epoch 60 Accuracy: 97.08%
# Epoch 60 Accuracy for unseendata: 94.63%
# Epoch 61 Accuracy: 97.25%
# Epoch 61 Accuracy for unseendata: 96.20%
# Epoch 62 Accuracy: 97.25%
# Epoch 62 Accuracy for unseendata: 96.43%
# Epoch 63 Accuracy: 97.23%
# Epoch 63 Accuracy for unseendata: 97.03%
# Epoch 64 Accuracy: 97.14%
# Epoch 64 Accuracy for unseendata: 97.30%
# Epoch 65 Accuracy: 97.46%
# Epoch 65 Accuracy for unseendata: 97.86%
# Epoch 66 Accuracy: 97.52%
# Epoch 66 Accuracy for unseendata: 97.40%
# Epoch 67 Accuracy: 97.52%
# Epoch 67 Accuracy for unseendata: 97.60%
# Epoch 68 Accuracy: 97.33%
# Epoch 68 Accuracy for unseendata: 98.50%
# Epoch 69 Accuracy: 97.37%
# Epoch 69 Accuracy for unseendata: 97.70%
# Epoch 70 Accuracy: 97.54%
# Epoch 70 Accuracy for unseendata: 97.40%
# Epoch 71 Accuracy: 97.54%
# Epoch 71 Accuracy for unseendata: 96.90%
# Epoch 72 Accuracy: 97.31%
# Epoch 72 Accuracy for unseendata: 97.10%
# Epoch 73 Accuracy: 97.37%
# Epoch 73 Accuracy for unseendata: 94.69%
# Epoch 74 Accuracy: 97.46%
# Epoch 74 Accuracy for unseendata: 95.76%
# Epoch 75 Accuracy: 97.46%
# Epoch 75 Accuracy for unseendata: 95.63%
# Epoch 1 Accuracy: 89.41%
# Epoch 1 Accuracy for unseendata: 94.46%
# Epoch 2 Accuracy: 92.04%
# Epoch 2 Accuracy for unseendata: 95.73%
# Epoch 3 Accuracy: 94.12%
# Epoch 3 Accuracy for unseendata: 96.10%
# Epoch 4 Accuracy: 95.04%
# Epoch 4 Accuracy for unseendata: 95.63%
# Epoch 5 Accuracy: 95.39%
# Epoch 5 Accuracy for unseendata: 96.40%
# Epoch 6 Accuracy: 94.89%
# Epoch 6 Accuracy for unseendata: 96.30%
# Epoch 7 Accuracy: 95.54%
# Epoch 7 Accuracy for unseendata: 96.40%
# Epoch 8 Accuracy: 96.04%
# Epoch 8 Accuracy for unseendata: 96.80%
# Epoch 9 Accuracy: 95.95%
# Epoch 9 Accuracy for unseendata: 98.43%
# Epoch 10 Accuracy: 96.25%
# Epoch 10 Accuracy for unseendata: 97.63%
# Epoch 11 Accuracy: 96.27%
# Epoch 11 Accuracy for unseendata: 96.50%
# Epoch 12 Accuracy: 96.14%
# Epoch 12 Accuracy for unseendata: 97.80%
# Epoch 13 Accuracy: 96.48%
# Epoch 13 Accuracy for unseendata: 97.40%
# Epoch 14 Accuracy: 95.45%
# Epoch 14 Accuracy for unseendata: 96.93%
# Epoch 15 Accuracy: 95.98%
# Epoch 15 Accuracy for unseendata: 96.43%
# Epoch 16 Accuracy: 96.56%
# Epoch 16 Accuracy for unseendata: 95.10%
# Epoch 17 Accuracy: 95.60%
# Epoch 17 Accuracy for unseendata: 97.03%
# Epoch 18 Accuracy: 95.79%
# Epoch 18 Accuracy for unseendata: 97.73%
# Epoch 19 Accuracy: 96.12%
# Epoch 19 Accuracy for unseendata: 96.70%
# Epoch 20 Accuracy: 96.43%
# Epoch 20 Accuracy for unseendata: 97.86%
# Epoch 21 Accuracy: 95.66%
# Epoch 21 Accuracy for unseendata: 98.40%
# Epoch 22 Accuracy: 96.64%
# Epoch 22 Accuracy for unseendata: 97.63%
# Epoch 23 Accuracy: 96.79%
# Epoch 23 Accuracy for unseendata: 96.00%
# Epoch 24 Accuracy: 96.60%
# Epoch 24 Accuracy for unseendata: 94.79%
# Epoch 25 Accuracy: 96.68%
# Epoch 25 Accuracy for unseendata: 93.66%
# Epoch 26 Accuracy: 97.00%
# Epoch 26 Accuracy for unseendata: 95.33%
# Epoch 27 Accuracy: 97.19%
# Epoch 27 Accuracy for unseendata: 96.26%
# Epoch 28 Accuracy: 96.66%
# Epoch 28 Accuracy for unseendata: 98.30%
# Epoch 29 Accuracy: 96.39%
# Epoch 29 Accuracy for unseendata: 98.50%
# Epoch 30 Accuracy: 96.50%
# Epoch 30 Accuracy for unseendata: 97.63%
# Epoch 31 Accuracy: 96.96%
# Epoch 31 Accuracy for unseendata: 96.80%
# Epoch 32 Accuracy: 97.25%
# Epoch 32 Accuracy for unseendata: 95.63%
# Epoch 33 Accuracy: 97.23%
# Epoch 33 Accuracy for unseendata: 95.56%
# Epoch 34 Accuracy: 97.19%
# Epoch 34 Accuracy for unseendata: 96.63%
# Epoch 35 Accuracy: 97.19%
# Epoch 35 Accuracy for unseendata: 95.36%
# Epoch 36 Accuracy: 97.33%
# Epoch 36 Accuracy for unseendata: 95.96%
# Epoch 37 Accuracy: 97.29%
# Epoch 37 Accuracy for unseendata: 96.70%
# Epoch 38 Accuracy: 97.23%
# Epoch 38 Accuracy for unseendata: 96.33%
# Epoch 39 Accuracy: 97.33%
# Epoch 39 Accuracy for unseendata: 96.93%
# Epoch 40 Accuracy: 97.12%
# Epoch 40 Accuracy for unseendata: 97.90%
# Epoch 41 Accuracy: 97.16%
# Epoch 41 Accuracy for unseendata: 98.13%
# Epoch 42 Accuracy: 96.96%
# Epoch 42 Accuracy for unseendata: 98.10%
# Epoch 43 Accuracy: 97.08%
# Epoch 43 Accuracy for unseendata: 98.13%
# Epoch 44 Accuracy: 97.00%
# Epoch 44 Accuracy for unseendata: 97.16%
# Epoch 45 Accuracy: 97.02%
# Epoch 45 Accuracy for unseendata: 96.90%
# Epoch 46 Accuracy: 97.08%
# Epoch 46 Accuracy for unseendata: 97.73%
# Epoch 47 Accuracy: 97.29%
# Epoch 47 Accuracy for unseendata: 97.53%
# Epoch 48 Accuracy: 96.91%
# Epoch 48 Accuracy for unseendata: 96.96%
# Epoch 49 Accuracy: 97.06%
# Epoch 49 Accuracy for unseendata: 96.56%
# Epoch 50 Accuracy: 96.93%
# Epoch 50 Accuracy for unseendata: 97.03%
# Epoch 51 Accuracy: 96.91%
# Epoch 51 Accuracy for unseendata: 96.86%
# Epoch 52 Accuracy: 97.00%
# Epoch 52 Accuracy for unseendata: 97.53%
# Epoch 53 Accuracy: 97.00%
# Epoch 53 Accuracy for unseendata: 97.76%
# Epoch 54 Accuracy: 97.14%
# Epoch 54 Accuracy for unseendata: 98.37%
# Epoch 55 Accuracy: 97.39%
# Epoch 55 Accuracy for unseendata: 97.73%
# Epoch 56 Accuracy: 97.14%
# Epoch 56 Accuracy for unseendata: 96.76%
# Epoch 57 Accuracy: 97.06%
# Epoch 57 Accuracy for unseendata: 96.53%
# Epoch 58 Accuracy: 96.87%
# Epoch 58 Accuracy for unseendata: 95.16%
# Epoch 59 Accuracy: 96.89%
# Epoch 59 Accuracy for unseendata: 96.36%
# Epoch 60 Accuracy: 96.75%
# Epoch 60 Accuracy for unseendata: 96.70%
# Epoch 61 Accuracy: 96.83%
# Epoch 61 Accuracy for unseendata: 96.33%
# Epoch 62 Accuracy: 96.83%
# Epoch 62 Accuracy for unseendata: 96.36%
# Epoch 63 Accuracy: 96.89%
# Epoch 63 Accuracy for unseendata: 96.40%
# Epoch 64 Accuracy: 96.79%
# Epoch 64 Accuracy for unseendata: 97.06%
# Epoch 65 Accuracy: 96.79%
# Epoch 65 Accuracy for unseendata: 97.33%
# Epoch 66 Accuracy: 96.96%
# Epoch 66 Accuracy for unseendata: 97.40%
# Epoch 67 Accuracy: 96.89%
# Epoch 67 Accuracy for unseendata: 97.20%
# Epoch 68 Accuracy: 97.19%
# Epoch 68 Accuracy for unseendata: 97.23%
# Epoch 69 Accuracy: 97.16%
# Epoch 69 Accuracy for unseendata: 96.86%
# Epoch 70 Accuracy: 97.06%
# Epoch 70 Accuracy for unseendata: 96.46%
# Epoch 71 Accuracy: 97.12%
# Epoch 71 Accuracy for unseendata: 96.90%
# Epoch 72 Accuracy: 97.08%
# Epoch 72 Accuracy for unseendata: 96.60%
# Epoch 73 Accuracy: 97.06%
# Epoch 73 Accuracy for unseendata: 96.83%
# Epoch 74 Accuracy: 97.04%
# Epoch 74 Accuracy for unseendata: 96.33%
# Epoch 75 Accuracy: 97.06%
# Epoch 75 Accuracy for unseendata: 96.06%
# Epoch 1 Accuracy: 89.62%
# Epoch 1 Accuracy for unseendata: 92.59%
# Epoch 2 Accuracy: 92.41%
# Epoch 2 Accuracy for unseendata: 92.23%
# Epoch 3 Accuracy: 94.33%
# Epoch 3 Accuracy for unseendata: 96.50%
# Epoch 4 Accuracy: 94.62%
# Epoch 4 Accuracy for unseendata: 95.40%
# Epoch 5 Accuracy: 95.10%
# Epoch 5 Accuracy for unseendata: 96.50%
# Epoch 6 Accuracy: 95.08%
# Epoch 6 Accuracy for unseendata: 96.13%
# Epoch 7 Accuracy: 94.97%
# Epoch 7 Accuracy for unseendata: 95.90%
# Epoch 8 Accuracy: 95.75%
# Epoch 8 Accuracy for unseendata: 97.83%
# Epoch 9 Accuracy: 95.91%
# Epoch 9 Accuracy for unseendata: 96.30%
# Epoch 10 Accuracy: 96.12%
# Epoch 10 Accuracy for unseendata: 96.50%
# Epoch 11 Accuracy: 95.66%
# Epoch 11 Accuracy for unseendata: 98.40%
# Epoch 12 Accuracy: 95.50%
# Epoch 12 Accuracy for unseendata: 98.23%
# Epoch 13 Accuracy: 95.87%
# Epoch 13 Accuracy for unseendata: 97.43%
# Epoch 14 Accuracy: 96.43%
# Epoch 14 Accuracy for unseendata: 96.23%
# Epoch 15 Accuracy: 96.33%
# Epoch 15 Accuracy for unseendata: 96.66%
# Epoch 16 Accuracy: 95.52%
# Epoch 16 Accuracy for unseendata: 98.26%
# Epoch 17 Accuracy: 96.31%
# Epoch 17 Accuracy for unseendata: 97.46%
# Epoch 18 Accuracy: 96.35%
# Epoch 18 Accuracy for unseendata: 97.06%
# Epoch 19 Accuracy: 95.23%
# Epoch 19 Accuracy for unseendata: 97.93%
# Epoch 20 Accuracy: 96.00%
# Epoch 20 Accuracy for unseendata: 97.63%
# Epoch 21 Accuracy: 96.21%
# Epoch 21 Accuracy for unseendata: 98.10%
# Epoch 22 Accuracy: 96.81%
# Epoch 22 Accuracy for unseendata: 97.90%
# Epoch 23 Accuracy: 96.41%
# Epoch 23 Accuracy for unseendata: 97.63%
# Epoch 24 Accuracy: 96.35%
# Epoch 24 Accuracy for unseendata: 98.00%
# Epoch 25 Accuracy: 96.35%
# Epoch 25 Accuracy for unseendata: 97.33%
# Epoch 26 Accuracy: 96.52%
# Epoch 26 Accuracy for unseendata: 97.90%
# Epoch 27 Accuracy: 96.27%
# Epoch 27 Accuracy for unseendata: 97.66%
# Epoch 28 Accuracy: 96.43%
# Epoch 28 Accuracy for unseendata: 97.03%
# Epoch 29 Accuracy: 96.56%
# Epoch 29 Accuracy for unseendata: 96.96%
# Epoch 30 Accuracy: 96.68%
# Epoch 30 Accuracy for unseendata: 97.20%
# Epoch 31 Accuracy: 96.71%
# Epoch 31 Accuracy for unseendata: 97.50%
# Epoch 32 Accuracy: 96.79%
# Epoch 32 Accuracy for unseendata: 97.86%
# Epoch 33 Accuracy: 96.35%
# Epoch 33 Accuracy for unseendata: 98.16%
# Epoch 34 Accuracy: 96.02%
# Epoch 34 Accuracy for unseendata: 98.73%
# Epoch 35 Accuracy: 96.35%
# Epoch 35 Accuracy for unseendata: 98.50%
# Epoch 36 Accuracy: 96.81%
# Epoch 36 Accuracy for unseendata: 96.73%
# Epoch 37 Accuracy: 96.60%
# Epoch 37 Accuracy for unseendata: 96.40%
# Epoch 38 Accuracy: 96.66%
# Epoch 38 Accuracy for unseendata: 95.66%
# Epoch 39 Accuracy: 96.46%
# Epoch 39 Accuracy for unseendata: 94.56%
# Epoch 40 Accuracy: 96.87%
# Epoch 40 Accuracy for unseendata: 97.16%
# Epoch 41 Accuracy: 96.93%
# Epoch 41 Accuracy for unseendata: 97.90%
# Epoch 42 Accuracy: 97.12%
# Epoch 42 Accuracy for unseendata: 98.20%
# Epoch 43 Accuracy: 97.14%
# Epoch 43 Accuracy for unseendata: 98.13%
# Epoch 44 Accuracy: 96.87%
# Epoch 44 Accuracy for unseendata: 97.83%
# Epoch 45 Accuracy: 96.62%
# Epoch 45 Accuracy for unseendata: 98.16%
# Epoch 46 Accuracy: 96.79%
# Epoch 46 Accuracy for unseendata: 98.16%
# Epoch 47 Accuracy: 96.85%
# Epoch 47 Accuracy for unseendata: 97.96%
# Epoch 48 Accuracy: 96.41%
# Epoch 48 Accuracy for unseendata: 98.03%
# Epoch 49 Accuracy: 96.56%
# Epoch 49 Accuracy for unseendata: 97.30%
# Epoch 50 Accuracy: 96.91%
# Epoch 50 Accuracy for unseendata: 97.33%
# Epoch 51 Accuracy: 96.83%
# Epoch 51 Accuracy for unseendata: 96.46%
# Epoch 52 Accuracy: 97.08%
# Epoch 52 Accuracy for unseendata: 97.43%
# Epoch 53 Accuracy: 97.25%
# Epoch 53 Accuracy for unseendata: 97.53%
# Epoch 54 Accuracy: 97.25%
# Epoch 54 Accuracy for unseendata: 97.50%
# Epoch 55 Accuracy: 97.48%
# Epoch 55 Accuracy for unseendata: 97.56%
# Epoch 56 Accuracy: 97.00%
# Epoch 56 Accuracy for unseendata: 96.70%
# Epoch 57 Accuracy: 97.27%
# Epoch 57 Accuracy for unseendata: 96.76%
# Epoch 58 Accuracy: 97.21%
# Epoch 58 Accuracy for unseendata: 96.43%
# Epoch 59 Accuracy: 97.25%
# Epoch 59 Accuracy for unseendata: 96.56%
# Epoch 60 Accuracy: 97.06%
# Epoch 60 Accuracy for unseendata: 97.33%
# Epoch 61 Accuracy: 97.00%
# Epoch 61 Accuracy for unseendata: 97.53%
# Epoch 62 Accuracy: 96.81%
# Epoch 62 Accuracy for unseendata: 98.57%
# Epoch 63 Accuracy: 96.96%
# Epoch 63 Accuracy for unseendata: 98.13%
# Epoch 64 Accuracy: 97.12%
# Epoch 64 Accuracy for unseendata: 98.33%
# Epoch 65 Accuracy: 96.96%
# Epoch 65 Accuracy for unseendata: 98.40%
# Epoch 66 Accuracy: 96.83%
# Epoch 66 Accuracy for unseendata: 98.03%
# Epoch 67 Accuracy: 97.00%
# Epoch 67 Accuracy for unseendata: 97.33%
# Epoch 68 Accuracy: 97.08%
# Epoch 68 Accuracy for unseendata: 97.06%
# Epoch 69 Accuracy: 96.93%
# Epoch 69 Accuracy for unseendata: 97.46%
# Epoch 70 Accuracy: 97.21%
# Epoch 70 Accuracy for unseendata: 96.63%
# Epoch 71 Accuracy: 97.21%
# Epoch 71 Accuracy for unseendata: 96.43%
# Epoch 72 Accuracy: 97.14%
# Epoch 72 Accuracy for unseendata: 97.10%
# Epoch 73 Accuracy: 97.29%
# Epoch 73 Accuracy for unseendata: 97.66%
# Epoch 74 Accuracy: 97.31%
# Epoch 74 Accuracy for unseendata: 98.06%
# Epoch 75 Accuracy: 97.06%
# Epoch 75 Accuracy for unseendata: 98.30%
# Epoch 1 Accuracy: 89.10%
# Epoch 1 Accuracy for unseendata: 93.79%
# Epoch 2 Accuracy: 92.72%
# Epoch 2 Accuracy for unseendata: 94.36%
# Epoch 3 Accuracy: 93.89%
# Epoch 3 Accuracy for unseendata: 97.03%
# Epoch 4 Accuracy: 94.60%
# Epoch 4 Accuracy for unseendata: 96.70%
# Epoch 5 Accuracy: 94.95%
# Epoch 5 Accuracy for unseendata: 96.20%
# Epoch 6 Accuracy: 95.73%
# Epoch 6 Accuracy for unseendata: 96.90%
# Epoch 7 Accuracy: 95.60%
# Epoch 7 Accuracy for unseendata: 96.70%
# Epoch 8 Accuracy: 96.10%
# Epoch 8 Accuracy for unseendata: 96.93%
# Epoch 9 Accuracy: 96.12%
# Epoch 9 Accuracy for unseendata: 95.46%
# Epoch 10 Accuracy: 95.98%
# Epoch 10 Accuracy for unseendata: 96.96%
# Epoch 11 Accuracy: 96.02%
# Epoch 11 Accuracy for unseendata: 97.13%
# Epoch 12 Accuracy: 95.93%
# Epoch 12 Accuracy for unseendata: 97.83%
# Epoch 13 Accuracy: 95.79%
# Epoch 13 Accuracy for unseendata: 97.20%
# Epoch 14 Accuracy: 96.31%
# Epoch 14 Accuracy for unseendata: 95.83%
# Epoch 15 Accuracy: 96.75%
# Epoch 15 Accuracy for unseendata: 96.63%
# Epoch 16 Accuracy: 96.54%
# Epoch 16 Accuracy for unseendata: 96.93%
# Epoch 17 Accuracy: 96.29%
# Epoch 17 Accuracy for unseendata: 98.30%
# Epoch 18 Accuracy: 96.85%
# Epoch 18 Accuracy for unseendata: 97.50%
# Epoch 19 Accuracy: 96.04%
# Epoch 19 Accuracy for unseendata: 98.00%
# Epoch 20 Accuracy: 96.27%
# Epoch 20 Accuracy for unseendata: 98.10%
# Epoch 21 Accuracy: 96.75%
# Epoch 21 Accuracy for unseendata: 98.43%
# Epoch 22 Accuracy: 96.25%
# Epoch 22 Accuracy for unseendata: 97.70%
# Epoch 23 Accuracy: 96.33%
# Epoch 23 Accuracy for unseendata: 97.56%
# Epoch 24 Accuracy: 96.85%
# Epoch 24 Accuracy for unseendata: 96.53%
# Epoch 25 Accuracy: 96.50%
# Epoch 25 Accuracy for unseendata: 96.36%
# Epoch 26 Accuracy: 96.43%
# Epoch 26 Accuracy for unseendata: 96.93%
# Epoch 27 Accuracy: 96.87%
# Epoch 27 Accuracy for unseendata: 98.16%
# Epoch 28 Accuracy: 96.64%
# Epoch 28 Accuracy for unseendata: 98.63%
# Epoch 29 Accuracy: 96.73%
# Epoch 29 Accuracy for unseendata: 98.16%
# Epoch 30 Accuracy: 96.64%
# Epoch 30 Accuracy for unseendata: 98.10%
# Epoch 31 Accuracy: 96.91%
# Epoch 31 Accuracy for unseendata: 96.70%
# Epoch 32 Accuracy: 96.66%
# Epoch 32 Accuracy for unseendata: 96.70%
# Epoch 33 Accuracy: 96.87%
# Epoch 33 Accuracy for unseendata: 95.90%
# Epoch 34 Accuracy: 97.14%
# Epoch 34 Accuracy for unseendata: 96.93%
# Epoch 35 Accuracy: 97.08%
# Epoch 35 Accuracy for unseendata: 96.66%
# Epoch 36 Accuracy: 97.02%
# Epoch 36 Accuracy for unseendata: 97.46%
# Epoch 37 Accuracy: 97.00%
# Epoch 37 Accuracy for unseendata: 97.16%
# Epoch 38 Accuracy: 97.02%
# Epoch 38 Accuracy for unseendata: 97.43%
# Epoch 39 Accuracy: 96.77%
# Epoch 39 Accuracy for unseendata: 97.96%
# Epoch 40 Accuracy: 96.79%
# Epoch 40 Accuracy for unseendata: 98.26%
# Epoch 41 Accuracy: 96.98%
# Epoch 41 Accuracy for unseendata: 98.13%
# Epoch 42 Accuracy: 97.02%
# Epoch 42 Accuracy for unseendata: 98.06%
# Epoch 43 Accuracy: 96.91%
# Epoch 43 Accuracy for unseendata: 98.16%
# Epoch 44 Accuracy: 96.96%
# Epoch 44 Accuracy for unseendata: 96.70%
# Epoch 45 Accuracy: 96.87%
# Epoch 45 Accuracy for unseendata: 96.80%
# Epoch 46 Accuracy: 96.75%
# Epoch 46 Accuracy for unseendata: 96.56%
# Epoch 47 Accuracy: 96.87%
# Epoch 47 Accuracy for unseendata: 95.96%
# Epoch 48 Accuracy: 96.83%
# Epoch 48 Accuracy for unseendata: 97.10%
# Epoch 49 Accuracy: 97.10%
# Epoch 49 Accuracy for unseendata: 97.36%
# Epoch 50 Accuracy: 97.02%
# Epoch 50 Accuracy for unseendata: 98.00%
# Epoch 51 Accuracy: 96.71%
# Epoch 51 Accuracy for unseendata: 98.03%
# Epoch 52 Accuracy: 96.93%
# Epoch 52 Accuracy for unseendata: 98.47%
# Epoch 53 Accuracy: 96.89%
# Epoch 53 Accuracy for unseendata: 98.30%
# Epoch 54 Accuracy: 96.75%
# Epoch 54 Accuracy for unseendata: 98.53%
# Epoch 55 Accuracy: 96.58%
# Epoch 55 Accuracy for unseendata: 97.30%
# Epoch 56 Accuracy: 96.64%
# Epoch 56 Accuracy for unseendata: 96.83%
# Epoch 57 Accuracy: 96.81%
# Epoch 57 Accuracy for unseendata: 96.73%
# Epoch 58 Accuracy: 96.60%
# Epoch 58 Accuracy for unseendata: 97.70%
# Epoch 59 Accuracy: 97.10%
# Epoch 59 Accuracy for unseendata: 96.96%
# Epoch 60 Accuracy: 97.08%
# Epoch 60 Accuracy for unseendata: 96.93%
# Epoch 61 Accuracy: 96.81%
# Epoch 61 Accuracy for unseendata: 97.46%
# Epoch 62 Accuracy: 96.81%
# Epoch 62 Accuracy for unseendata: 97.20%
# Epoch 63 Accuracy: 96.50%
# Epoch 63 Accuracy for unseendata: 97.36%
# Epoch 64 Accuracy: 96.58%
# Epoch 64 Accuracy for unseendata: 96.43%
# Epoch 65 Accuracy: 96.52%
# Epoch 65 Accuracy for unseendata: 96.26%
# Epoch 66 Accuracy: 96.54%
# Epoch 66 Accuracy for unseendata: 96.43%
# Epoch 67 Accuracy: 96.66%
# Epoch 67 Accuracy for unseendata: 96.50%
# Epoch 68 Accuracy: 96.56%
# Epoch 68 Accuracy for unseendata: 98.03%
# Epoch 69 Accuracy: 96.37%
# Epoch 69 Accuracy for unseendata: 98.47%
# Epoch 70 Accuracy: 96.66%
# Epoch 70 Accuracy for unseendata: 98.57%
# Epoch 71 Accuracy: 96.71%
# Epoch 71 Accuracy for unseendata: 98.83%
# Epoch 72 Accuracy: 96.89%
# Epoch 72 Accuracy for unseendata: 98.57%
# Epoch 73 Accuracy: 97.29%
# Epoch 73 Accuracy for unseendata: 98.47%
# Epoch 74 Accuracy: 97.02%
# Epoch 74 Accuracy for unseendata: 97.80%
# Epoch 75 Accuracy: 96.85%
# Epoch 75 Accuracy for unseendata: 97.36%
# /tmp/ipykernel_758677/2156954925.py:68: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   plot = sns.lineplot(x='Epoch', y='Accuracy', data=data, marker='o', palette="tab10", linewidth=2.5)
# /tmp/ipykernel_758677/2156954925.py:79: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   plot = sns.lineplot(x='Epoch', y='Accuracy', data=data_unseen, marker='o', palette="tab10", linewidth=2.5)

# %%
Y_pred = tm.predict(flattened_data)
repeated_y_data = repeated_y_data.astype(Y_pred.dtype)
conf_matrix = confusion_matrix(repeated_y_data, Y_pred)

# Print the confusion matrix
print("Confusion Matrix:")
print(conf_matrix)

# Plotting the confusion matrix
plt.figure(figsize=(10, 7))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", xticklabels=True, yticklabels=True)
plt.title('CTM Thermometer Test')
plt.ylabel('Actual label')
plt.xlabel('Predicted label')
# plt.savefig('../plot/CM_CWRU_CTM_thermometer_test.pdf') # Option for saving plot
plt.show()


Y_pred = tm.predict(flattened_data_test)
repeated_y_data_test = repeated_y_data_test.astype(Y_pred.dtype)
conf_matrix = confusion_matrix(repeated_y_data_test, Y_pred)

# Print the confusion matrix
print("Confusion Matrix:")
print(conf_matrix)

# Plotting the confusion matrix
plt.figure(figsize=(10, 7))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", xticklabels=True, yticklabels=True)
plt.title('CTM Thermometer Benchmark')
plt.ylabel('Actual label')
plt.xlabel('Predicted label')
# plt.savefig('../plot/CM_CWRU_CTM_thermometer_benchmark.pdf') # Option for saving plot
plt.show()
# Out:
# Confusion Matrix:
# [[7861   19  112]
#  [  32 7958    2]
#  [ 115    2 7875]]
# Confusion Matrix:
# [[920  79   0]
#  [  0 999   0]
#  [  0   0 999]]

# %%
print(C)
print(T)
print(s)
# Out:
# 490
# 17.870698542251617
# 12.341961284328281
